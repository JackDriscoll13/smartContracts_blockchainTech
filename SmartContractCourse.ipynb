# %% [markdown]
# Jack Driscoll <br>
# Smart Contract Course Notes <br>
# Start Date 7/25/22 </br>
# [YouTube Course](https://www.youtube.com/watch?v=M576WGiDBdQ)

# %% [markdown]
# ### <span style="color:Yellow"> Lesson 0: Welcome To Blockchain </span>
#
# <span style="color:Yellow">  0.0 History of Blockchain </span>
#
# [Ethereum Whitepaper](https://ethereum.org/en/whitepaper/) <br>
#
# <span style="color:Green">  Blockchain basics:</span> <br>
#
# - Decentralized smart contracts exist on ethereum. <br>
# - Smart contracts allow for agreements without a third party intermediary. They are entirely written in code. <br>
# - The oracle problem. Smart contracts need to interact with real world data. Thats why we have hybrid smart contracts. Using oracle applications. <br>
# - Chainlink is an oracle application. Chainlink is the most popular oracle application.  <br>
#
# <span style="color:Green">  Advantages to BlockChain: </span> <br>
#
# 1. Decentralized. No central entity to control financial markets, like bannks. <br>
# 2. Transparency. Can see every interaction that occurs on public ledger <br>
# 3. Speed. Allows for faster <br>
# 4. Security and immutability. <br>
# 5. Removal of counterparty Risk. Move away from political brand based agreement.  <br>
# 6. Allow us to engage in trust minimized agreement. We don't have to trust other people to fufill our agreements. "trustless" <br>
#
# <span style="color:Green">  Transactions 101 - Metamask: </span> <br>
#
# - Setting up metamesk: Mnemonic list of words can access all acounts, private key can access 1 wallet. <br>
# - Test applications on things not on the main net like rinkyby <br>
# - Using etherscan to view and analyze transactions <br>
# - Gas fees. You pay the miners/the block chain a fee. Gas x Gwei. <br>
# - Block space. Nodes can only put so many transactions into a block. They are incentivized by those who pay a higher fee (gas). <br>
# - Gwei is directly related to how many people are using the network. <br>
#
#
#  <span style="color:Yellow">  0.1 Mechanisms of BlockChain </span>
#
# Blockchains are democraticly driven. <br>
# Blockchains are deterministic systems.
#
# <span style="color:Green"> How it Works: </span>
#
# - [BlockChain 101 Video](https://www.youtube.com/watch?v=_160oMzblY8)
# - [Visualising Blockchain Practice](https://www.andersbrownworth.com/blockchain)
# - Hash: a unique fixed length streng. Meant to identify a piece of data. Created by putting data into a hash function (algorithm)
# - The hash corresponds to the specific data in the block. ie, one block.
# - Nonce: the nonce is the solution to the block, the number where the specifc data matches the corresponding hash.
# - NONCE + DATA (tx) = unique hash
# - A node gets paid to "mine" or solve the block, by matching the nonce to the specific hash requirement (i.e. 4 zeros at the start of the hash)
# - Prev: points to the hash of the previous block
# - Changing one piece of data invalidates the entire block chain
# - Peer to peer: Each peer (node), each independent node has the same power, a mechanism of checks and balances for checking to make sure the blockchain is correct. Matching (hashes)
# - TX: transaction data.
#
# <span style="color:Green"> Public vs. Private Keys: </span>
# - Private Key > Public Key > Address
# - You sign your transactions using a private key. That key then generates a signature.
# - Anyone can verify that your signature is correct using your public key. Kinda confused about how exactly this all works but idk if it really matters
# - KEEP PRIVATE KEY PRIVATE AT ALL TIMES
#
# <span style="color:Green"> Consensus: </span>
# - Consesus is the mechanism used to agree on the state of the blockchain.
# - Consessus is composed of 1. Chain selection   2. Sybil Resistance
#     - Sybil Reistance: A blockchains defense against people creating multiple identies (nodes) to have more power over the system
#       - Proof of work (PoW): Mining - solving the complex problem. Very computationally expensive. chains can change the block time by changing difficulty of problem.
#         - Pros: Great sybil resistance. cons: energy expensive and enviormentally impactful
#       - Proof of Stake (PoS): Staking ... Nodes put up colleteral as evidence that they will "behave" on the block. miners replaced by validators. Validators are stakers that are chosen randomly
#       - to  solve a block and then validated by the rest of the nodes
#         - Pros: great sybil resistance mechanism, uses less energy. Cons: slightly less decentralized because of cost of stake
#     - Chain Selection Rule:
#       - In nakamoto consesus, the longest chain wins.
#
# <span style="color:Green"> Types of Attacks That Can Happen: </span>
# - Sybil Attack: One user creates many nodes and uses lots of computational resources to gain unfair power. (less prevalent)
# - 51% attack: The longest chain is the correct one so long as it matches up with 51% of the rest of the network. (more prevalent) (someone )
#
# Blockchains are democraticly driven.
# Blockchains are deterministic systems.
#
# <span style="color:Green"> Scalability: </span>
# - Current eth isnt scalable because gas prices ultimate put a fininacial constraint on how many people can be using the network
# - Eth 2.0 is hoping to solve this by transitioning to sharding.
# - Sharding is basically multiple networks 'sharding' off of the main network or block chain. Shards derive their security from the main layer but allow for less gas by existing on a slightly different plain.
# - Layer 1: base layer blockchain implementation
# - Layer 2: any application built on top of a layer 1. Rollups fall into this category

# %%
with open("./simpleStorage.sol", "r") as file:
    simple_storage_file = file.read()
    print(simple_storage_file)
# Out:
# // SPDX-License-Identifier: MIT
# pragma solidity ^0.8.0;
#
# contract SimpleStorage {
#     // This is a comment in solidity
#
#     // This will get itiliazed to 0
#     // add keyword 'public' to this var to make it visible to public
#     uint256 favoriteNumber;
#
#     // structs
#     // Basically like a class, multiple atributes
#     struct People {
#         uint256 favoriteNumber;
#         string name;
#     }
#
#     // People public person = People({favoriteNumber: 2, name: "Jack"});
#
#     // creating array (dynamic not fixed)
#     People[] public people;
#
#     // Mapping, like a dictiontionary
#     // Mapp a string to a mathcing integer, a key to a valuue
#     mapping(string => uint256) public nameToNumber;
#
#     // Lets create a function
#     function store(uint256 _favoriteNumber) public {
#         favoriteNumber = _favoriteNumber;
#     }
#
#     function retrieve() public view returns (uint256) {
#         return favoriteNumber;
#     }
#
# ...

# %% [markdown]
# ### <span style="color:Yellow"> Lesson 1: Solidity 101 - Using Remix IDE  </span>
#
# <span style="color:Yellow"> 1.0 Basic Solidty </span>
#
# - SPDX License
# - Versioning (declare at start of contract )
# - Compiling (use brownie compile to compile code) (expand contracts down to almost machine code)
# - Variable types **[ uint256, int256, bool, string, address, bytes32 ]** declare before initializing
# - Comments "//"
# - Types of functions, ones that don't make a state change "view" (just look/ pull something) and "pure" (do pure math)
# - Ways of storing info in solidity, memory (delete after executing), storage (keep forever).
# - [Function Visibility] (https://docs.soliditylang.org/en/v0.7.3/contracts.html#visibility-and-getters)
# - Arrays and structs: mappings (like dicts), and arrays (dynamic and fixed)
#
# <span style="color:Yellow"> 1.1 Deploying to a Network </span>
#
# - "deploy" contracts to mainnet or test net, costs gas
# - Can interact with deployed contracts through predefined functions and functionality
# - Working with the EVM (ethereum virtual machine) (!need to review this concept)

# %% [markdown]
# ### <span style="color:Yellow"> Lesson 2: Contracts 102 - Storage Factory </span>
#
# <span style="color:Yellow"> 2.0  Factory Pattern </span>
#
# **- Factory pattern** ( storage factory )
#   - Import previous contract or any
#   - Need in same folder,
#   - We can deploy multiple contracts of the same type from one contract
#   - // SimpleStorageContract simpleStorage = new SimpleStorageContract(
#   - We can interact with differnt contracts using the array of contract addresses that we stored
#   - Basically works like an imported library, we can read in the contracts as an object and interact with individual contracts using their address, and apply theier core functionality in .methods. (sfStore)
#
# **- Inherithance**
# - Can inherhit all the functions from another contract
# - more to learn on this

# %% [markdown]
# ### <span style="color:Yellow"> Lesson 3: Payable Contracts </span>
#
# <span style="color:Yellow"> 3.0 Payable Function Types  </span>
#
# - Contracts can store and transfer value
# - Payable functions take transactions and allow for a value as a input parameter
# - msg.sender is the person who calls the function, the wallet the function is tied to.
# - msg.value is the value associated with the function call
# - Everything defaults to wei, the "cents" of eth, imperative to have accurate wei/gwei/eth converter
#
# <span style="color:Yellow"> 3.1 Oracles - getting external data  </span>
#
# - oracles like chain link are great for getting external data, like the value of eth or converting wei to eth
# - Get conversion rate /other data:
# - [https://data.chain.link/](https://data.chain.link/)
# - Oracles like chainlink are also decentralized
#
# <span style="color:Yellow"> 3.2 Advanced Solidity - NPM - aggregatorV3Interface   </span>
#
# - NPM is a repository of solidty code that allows you to work with preset solidty functions
# - We can import it, and interact with contracts that have those interface functions
# - We can basically use it to call on other functions like the one predeployed by chainlink
# - in order to interact with different contracts, you need address and ABI
# - Interfaces compile down to ABIS
#
# <span style="color:Yellow"> 3.3 Advanced Solidity - coding /syntax tips  </span>
#
# - Need to typecast every variable we declare!
# - tuples, in functions that return tuple, can get only one by putting commas (returns 6 items but we only want one:      (,,,myVariable,,) )
# - safemath, if too big (integer overflow), solidty will go over the limit and reset to 0, we can avoid this by using safemath
#
# PseudoCode excercise for one solidty function:
# - Can set a threshold by using a require within a function
#   - Excercise to require minimum of 50 usd.
#   - 0. Goal: require our fund function to have a minimum of 50 bucks
#   - 1. Define that minimum in wei
#   - 2. Convert 50$ us to the amount of wei, because this always changing, we need eth conversion rate
#   - 3. Return the eth conversion from the latestRoundData(), return it in getPrice function
#   - 4. Convert the value of a specific amount of wei in getConversionRate function, using the getPrice function
#   - 5. Require that the msg.value of our fund transaction be greater than 50USD
#
# - require function, stops a function with specified, predefined error
# - Revert, reverts transaction if error occurs
# - Constructor: a function that is called the instant a contract deploys, sets a variable like owner
# - Modifier: modifiers are used to change the behavior of functions in a declaritive way, a way of requiring a parameter = something we define. Can specify predefined moderators in the parameter of a function.
# - this: refers to the contract we are currently in. address(this) gives address of current contract
